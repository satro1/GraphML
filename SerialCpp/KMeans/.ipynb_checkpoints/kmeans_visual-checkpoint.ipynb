# %% [markdown]
# ### Visualization of KMeans grouping

# %%
import pandas as pd

df = pd.read_csv('output.txt') 

df
# Out:
#             x         y  cluster
# 0    0.094549  0.081738        0
# 1    0.045341  0.041420        0
# 2    0.086813  0.059197        0
# 3    0.383416  0.066842        1
# 4    0.262453  0.047464        1
# ..        ...       ...      ...
# 995  0.568109  0.211342        3
# 996  0.030379  0.582117        3
# 997  0.641647  0.155059        3
# 998  0.574306  0.368609        3
# 999  0.000595  0.000879        4
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

ax = df.plot.scatter(x='x', y='y',c='cluster', colormap='viridis')

x = df['x']
y = df['y']
c = df['cluster']



plt.scatter(x,y,c)
plt.show()
